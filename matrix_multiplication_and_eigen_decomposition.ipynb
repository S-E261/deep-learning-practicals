# %%
# !pip install keras
# Out:
# Collecting keras
#   Downloading keras-3.12.0-py3-none-any.whl (1.5 MB)
# Collecting h5py
#   Downloading h5py-3.15.1-cp310-cp310-win_amd64.whl (2.9 MB)
# Collecting numpy
#   Downloading numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
# Collecting optree
#   Downloading optree-0.18.0-cp310-cp310-win_amd64.whl (302 kB)
# Collecting ml-dtypes
#   Downloading ml_dtypes-0.5.4-cp310-cp310-win_amd64.whl (210 kB)
# Collecting namex
#   Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Requirement already satisfied: packaging in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from keras) (25.0)
# Collecting absl-py
#   Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
# Collecting rich
#   Downloading rich-14.2.0-py3-none-any.whl (243 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from optree->keras) (4.15.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from rich->keras) (2.19.2)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: mdurl, numpy, markdown-it-py, rich, optree, namex, ml-dtypes, h5py, absl-py, keras
# Successfully installed absl-py-2.3.1 h5py-3.15.1 keras-3.12.0 markdown-it-py-4.0.0 mdurl-0.1.2 ml-dtypes-0.5.4 namex-0.1.0 numpy-2.2.6 optree-0.18.0 rich-14.2.0
# WARNING: You are using pip version 21.2.3; however, version 25.3 is available.
# You should consider upgrading via the 'C:\Users\Mscit8\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.20.0-cp310-cp310-win_amd64.whl (331.7 MB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-3.2.0-py3-none-any.whl (7.7 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.76.0-cp310-cp310-win_amd64.whl (4.7 MB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.32.5)
# Collecting wrapt>=1.11.0
#   Downloading wrapt-2.0.1-cp310-cp310-win_amd64.whl (60 kB)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: packaging in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (25.0)
# Collecting libclang>=13.0.0
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Collecting tensorboard~=2.20.0
#   Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.5.4)
# Collecting flatbuffers>=24.3.25
#   Downloading flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Collecting google_pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting protobuf>=5.28.0
#   Downloading protobuf-6.33.2-cp310-abi3-win_amd64.whl (436 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: setuptools in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.12.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.2.6)
# Collecting opt_einsum>=2.3.2
#   Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.7.0-py3-none-any.whl (22 kB)
# Collecting wheel<1.0,>=0.23.0
#   Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Requirement already satisfied: namex in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: rich in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: optree in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Collecting werkzeug>=1.0.1
#   Downloading werkzeug-3.1.4-py3-none-any.whl (224 kB)
# Collecting pillow
#   Downloading pillow-12.0.0-cp310-cp310-win_amd64.whl (7.0 MB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Collecting markdown>=2.6.8
#   Downloading markdown-3.10-py3-none-any.whl (107 kB)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mscit8\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Installing collected packages: wheel, werkzeug, tensorboard-data-server, protobuf, pillow, markdown, grpcio, wrapt, termcolor, tensorboard, opt-einsum, libclang, google-pasta, gast, flatbuffers, astunparse, tensorflow
# Successfully installed astunparse-1.6.3 flatbuffers-25.9.23 gast-0.7.0 google-pasta-0.2.0 grpcio-1.76.0 libclang-18.1.1 markdown-3.10 opt-einsum-3.4.0 pillow-12.0.0 protobuf-6.33.2 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 termcolor-3.2.0 werkzeug-3.1.4 wheel-0.45.1 wrapt-2.0.1
# WARNING: You are using pip version 21.2.3; however, version 25.3 is available.
# You should consider upgrading via the 'C:\Users\Mscit8\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import keras

# %%
import tensorflow as tf

# %%
 x=tf.constant([1,2,3,4,5,6],shape=[2,3])
x
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[1, 2, 3],
#        [4, 5, 6]], dtype=int32)>

# %%
y=tf.constant([7,8,9,10,11,12],shape=[3,2])
y
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[ 7,  8],
#        [ 9, 10],
#        [11, 12]], dtype=int32)>

# %%
z=tf.matmul(x,y)
z
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[ 58,  64],
#        [139, 154]], dtype=int32)>

# %%
A=tf.random.uniform([2,2],minval=3,maxval=10,dtype=tf.float32)
A
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[6.228286 , 6.569197 ],
#        [4.7863626, 3.6327891]], dtype=float32)>

# %%
eigen_values,eigen_vectors = tf.linalg.eigh(A)

# %%
print(eigen_values)
# Out:
# tf.Tensor([-0.02863775  9.889713  ], shape=(2,), dtype=float32)

# %%
print(eigen_vectors)
# Out:
# tf.Tensor(
# [[-0.6075828  0.7942564]
#  [ 0.7942564  0.6075828]], shape=(2, 2), dtype=float32)
